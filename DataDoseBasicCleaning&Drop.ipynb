# %% [markdown]
# > # **Import Libarary**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import re

# %% [markdown]
# > # **Import Dataset**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path = '/content/drive/MyDrive/DataDose_DEPI_Project/(CSV) New prices up to 03-08-2024.csv'
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#                                activeingredient  \
# 0  pseudoephedrine+paracetamol+chlorpheniramine
# 1  pseudoephedrine+paracetamol+chlorpheniramine
# 2                                  fluorouracil
# 3                                          agar
# 4                                   lactoferrin
#
#                                              company  \
# 0                                              hikma
# 1                                              hikma
# 2  shanghai xudong haipu pharmaceutical > acdima ...
# 3                                hexa pharma company
# 4                                         eva pharma
#
#                     created    form            group               id  \
# 0  2024-08-03 01:41:02.489Z   syrup       cold drugs  r4398b30b7ec826
# 1  2024-08-03 01:41:02.489Z  tablet       cold drugs  r2c089cc79207d2
# 2  2024-08-03 01:41:02.489Z    vial   antineoplastic  rf97db2c018adfb
# 3  2024-08-03 01:41:02.489Z  sachet         jaundice  r7117678f0c1580
# 4  2024-08-03 01:41:02.489Z  sachet  iron supplement  r34886d1d09f551
#
#    new_price                                       pharmacology        route  \
# 0       32.0  each 5 ml contains: paracetamol .. 160 mg chlo...  oral.liquid
# 1       24.0  indication: runny noses blocked noses and sinu...   oral.solid
# 2       50.0  description a pyrimidine analog that is an ant...    injection
# 3       75.0                                               agar          eff
# 4      324.0  ï- supports a healthy immune system for all fa...          eff
#
#                                   tradename                   updated
# 0        1 2 3 (one two three) syrup 120 ml  2024-08-03 01:41:02.489Z
# 1        1 2 3 (one two three) 20 f.c.tabs.  2024-08-03 01:41:02.489Z
# 2  5-fluorouracil-ebewe 250mg/5ml i.v. vial  2024-08-03 01:41:02.489Z
# 3                           mooagar sachets  2024-08-03 01:41:02.489Z
# 4   limitless lactoferrin 100 mg 30 sachets  2024-08-03 01:41:02.489Z

# %%
df.describe()
# Out:
#           new_price
# count  2.619900e+04
# mean   1.732760e+03
# std    2.101017e+05
# min    0.000000e+00
# 25%    1.900000e+01
# 50%    4.900000e+01
# 75%    1.200500e+02
# max    3.400000e+07

# %%
df.describe(include='object')
# Out:
#                    activeingredient     company                   created  \
# count                         23292       22517                     26201
# unique                         8387        4616                       462
# top     amoxicillin+clavulanic acid  eva pharma  2024-08-03 01:41:06.469Z
# freq                            119         424                       136
#
#           form      group               id  \
# count    26189      22061            26201
# unique      54       2161            26201
# top     tablet  hair care  r2ab1766f4afc8d
# freq      8134        926                1
#
#                                              pharmacology       route  \
# count                                               13319       25427
# unique                                               5412          18
# top     about pregabalin a gaba agonist anticonvulsant...  oral.solid
# freq                                                   79       11399
#
#                       tradename                   updated
# count                     26201                     26201
# unique                    26200                       462
# top     andogonium syrup 100 ml  2024-08-03 01:41:06.469Z
# freq                          2                       136

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26201 entries, 0 to 26200
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   activeingredient  23292 non-null  object
#  1   company           22517 non-null  object
#  2   created           26201 non-null  object
#  3   form              26189 non-null  object
#  4   group             22061 non-null  object
#  5   id                26201 non-null  object
#  6   new_price         26199 non-null  float64
#  7   pharmacology      13319 non-null  object
#  8   route             25427 non-null  object
#  9   tradename         26201 non-null  object
#  10  updated           26201 non-null  object
# dtypes: float64(1), object(10)
# memory usage: 2.2+ MB

# %% [markdown]
# > # **Start Cleaning**

# %%
df_clean = df.copy()

# %%
df_clean = df_clean.drop(columns=["updated", "created", "new_price", "id"])

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26201 entries, 0 to 26200
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   activeingredient  23292 non-null  object
#  1   company           22517 non-null  object
#  2   form              26189 non-null  object
#  3   group             22061 non-null  object
#  4   pharmacology      13319 non-null  object
#  5   route             25427 non-null  object
#  6   tradename         26201 non-null  object
# dtypes: object(7)
# memory usage: 1.4+ MB

# %%
df_clean.head()
# Out:
#                                activeingredient  \
# 0  pseudoephedrine+paracetamol+chlorpheniramine
# 1  pseudoephedrine+paracetamol+chlorpheniramine
# 2                                  fluorouracil
# 3                                          agar
# 4                                   lactoferrin
#
#                                              company    form            group  \
# 0                                              hikma   syrup       cold drugs
# 1                                              hikma  tablet       cold drugs
# 2  shanghai xudong haipu pharmaceutical > acdima ...    vial   antineoplastic
# 3                                hexa pharma company  sachet         jaundice
# 4                                         eva pharma  sachet  iron supplement
#
#                                         pharmacology        route  \
# 0  each 5 ml contains: paracetamol .. 160 mg chlo...  oral.liquid
# 1  indication: runny noses blocked noses and sinu...   oral.solid
# 2  description a pyrimidine analog that is an ant...    injection
# 3                                               agar          eff
# 4  ï- supports a healthy immune system for all fa...          eff
#
#                                   tradename
# 0        1 2 3 (one two three) syrup 120 ml
# 1        1 2 3 (one two three) 20 f.c.tabs.
# 2  5-fluorouracil-ebewe 250mg/5ml i.v. vial
# 3                           mooagar sachets
# 4   limitless lactoferrin 100 mg 30 sachets

# %%
df_clean.isnull().sum()
# Out:
# activeingredient     2909
# company              3684
# form                   12
# group                4140
# pharmacology        12882
# route                 774
# tradename               0
# dtype: int64

# %%
df_clean.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# > **Format Cols Names**

# %%
text_cols = [
    "activeingredient",
    "company",
    "form",
    "group",
    "route",
    "tradename"
]

for col in text_cols:
    df_clean[col] = (
        df_clean[col]
        .astype(str)
        .str.lower()
        .str.strip()
    )

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26201 entries, 0 to 26200
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   activeingredient  26201 non-null  object
#  1   company           26201 non-null  object
#  2   form              26201 non-null  object
#  3   group             26201 non-null  object
#  4   pharmacology      13319 non-null  object
#  5   route             26201 non-null  object
#  6   tradename         26201 non-null  object
# dtypes: object(7)
# memory usage: 1.4+ MB
